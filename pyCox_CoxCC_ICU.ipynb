# %%
import pandas as pd 
from pathlib import Path


data_path = Path('./PrecisionFDA/')
test_df = pd.read_csv( data_path / Path('pyCox_test_input_1000.csv'))

                                                                                                                 
final_df = pd.read_csv( data_path / Path('pyCox_train_input_1000_ICU.csv'))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn_pandas import DataFrameMapper

import torch
import torchtuples as tt

from pycox.datasets import metabric
from pycox.models import CoxCC
from pycox.evaluation import EvalSurv

# %%
c = final_df.columns
b = test_df.columns
cols_remove = []
for a in c:
    if a in b:
        cols_remove.append(a)
print(cols_remove)
# Out:
# ['Id', '1000126', '1014678', '1043400', '1049221', '1049630', '1049635', '105078', '105585', '106258', '106892', '1091392', '1094107', '1100184', '1114085', '1190795', '1234995', '1359133', '1363309', '1366343', '1367439', '1373463', '141918', '1534809', '1599803', '1601380', '1605257', '1652673', '1659149', '1659263', '1660014', '1665227', '1719286', '1723208', '1729584', '1732136', '1732186', '1734340', '1734919', '1735006', '1736776', '1736854', '1737449', '1740467', '1790099', '1791701', '1803932', '1804799', '1808217', '1809104', '1856546', '1860154', '1860480', '1870230', '1873983', '1946840', '197319', '197361', '197378', '197541', '197591', '197604', '198014', '198031', '198240', '198405', '198767', '199224', '200064', '2001499', '204892', '205532', '205923', '2119714', '2123111', '235389', '241834', '243670', '259255', '308182', '308192', '308971', '309043', '309045', '309097', '309362', '310261', '310325', '310385', '310436', '310798', '310965', '311372', '311700', '311989', '311995', '312615', '312617', '312938', '312961', '313002', '313185', '313572', '313782', '313820', '313988', '314231', '389221', '429503', '477045', '483438', '542347', '562251', '583214', '596926', '597195', '665078', '705129', '727762', '746030', '748856', '748879', '748962', '749762', '749785', '749882', '751905', '752899', '757594', '789980', '807283', '831533', '833036', '833135', '834061', '834102', '834357', '849574', '855332', '856980', '856987', '857005', '860975', '861467', '865098', '866414', '895994', '896209', '897122', '897718', '904419', '966222', '978950', '993452', '996740', '997223', '997488', '997501', '999967', 'Meds_1000126', 'Meds_1014678', 'Meds_1043400', 'Meds_1049221', 'Meds_1049630', 'Meds_1049635', 'Meds_105078', 'Meds_105585', 'Meds_106258', 'Meds_106892', 'Meds_1091392', 'Meds_1094107', 'Meds_1100184', 'Meds_1114085', 'Meds_1190795', 'Meds_1234995', 'Meds_1359133', 'Meds_1363309', 'Meds_1366343', 'Meds_1367439', 'Meds_1373463', 'Meds_141918', 'Meds_1534809', 'Meds_1599803', 'Meds_1601380', 'Meds_1605257', 'Meds_1652673', 'Meds_1659149', 'Meds_1659263', 'Meds_1660014', 'Meds_1665227', 'Meds_1719286', 'Meds_1723208', 'Meds_1729584', 'Meds_1732136', 'Meds_1732186', 'Meds_1734340', 'Meds_1734919', 'Meds_1735006', 'Meds_1736776', 'Meds_1736854', 'Meds_1737449', 'Meds_1740467', 'Meds_1790099', 'Meds_1791701', 'Meds_1803932', 'Meds_1804799', 'Meds_1808217', 'Meds_1809104', 'Meds_1856546', 'Meds_1860154', 'Meds_1860480', 'Meds_1870230', 'Meds_1873983', 'Meds_1946840', 'Meds_197319', 'Meds_197361', 'Meds_197378', 'Meds_197541', 'Meds_197591', 'Meds_197604', 'Meds_198014', 'Meds_198031', 'Meds_198240', 'Meds_198405', 'Meds_198767', 'Meds_199224', 'Meds_200064', 'Meds_2001499', 'Meds_204892', 'Meds_205532', 'Meds_205923', 'Meds_2119714', 'Meds_2123111', 'Meds_235389', 'Meds_241834', 'Meds_243670', 'Meds_259255', 'Meds_308182', 'Meds_308192', 'Meds_308971', 'Meds_309043', 'Meds_309045', 'Meds_309097', 'Meds_309362', 'Meds_310261', 'Meds_310325', 'Meds_310385', 'Meds_310436', 'Meds_310798', 'Meds_310965', 'Meds_311372', 'Meds_311700', 'Meds_311989', 'Meds_311995', 'Meds_312615', 'Meds_312617', 'Meds_312938', 'Meds_312961', 'Meds_313002', 'Meds_313185', 'Meds_313572', 'Meds_313782', 'Meds_313820', 'Meds_313988', 'Meds_314231', 'Meds_389221', 'Meds_429503', 'Meds_477045', 'Meds_483438', 'Meds_542347', 'Meds_562251', 'Meds_583214', 'Meds_596926', 'Meds_597195', 'Meds_665078', 'Meds_705129', 'Meds_727762', 'Meds_746030', 'Meds_748856', 'Meds_748879', 'Meds_748962', 'Meds_749762', 'Meds_749785', 'Meds_749882', 'Meds_751905', 'Meds_752899', 'Meds_757594', 'Meds_789980', 'Meds_807283', 'Meds_831533', 'Meds_833036', 'Meds_833135', 'Meds_834061', 'Meds_834102', 'Meds_834357', 'Meds_849574', 'Meds_855332', 'Meds_856980', 'Meds_856987', 'Meds_857005', 'Meds_860975', 'Meds_861467', 'Meds_865098', 'Meds_866414', 'Meds_895994', 'Meds_896209', 'Meds_897122', 'Meds_897718', 'Meds_904419', 'Meds_966222', 'Meds_978950', 'Meds_993452', 'Meds_996740 ...

# %%
#final_df = final_df.drop(columns=['VALUE'])
#cols_remove = cols_remove.remove('durration')
cols_remove.append('durration')
cols_remove.append('event')
#final_df = final_df[cols_remove]
#final_df = final_df.drop(columns= 'Unnamed: 0')
df_train = final_df
df_test = df_train.sample(frac=0.2)
df_train = df_train.drop(df_test.index)
df_val = df_train.sample(frac=0.2)
df_train = df_train.drop(df_val.index)
df_train.head()

      
cols = df_train.columns
stand_cols = []
leave_cols = []

i = 1
for i in range(len(cols)):
    if "_" in str(cols[i]):
        leave_cols.append(cols[i])
    else:
        stand_cols.append(cols[i])

stand_cols.remove('Id')
stand_cols.remove('durration')
stand_cols.remove('event')
print(stand_cols)
print(leave_cols)
# Out:
'Meds_860975', 'Meds_861467', 'Meds_865098', 'Meds_866414', 'Meds_895994', 'Meds_896209', 'Meds_897122', 'Meds_897718', 'Meds_904419', 'Meds_966222', 'Meds_978950', 'Meds_993452', 'Meds_996740', 'Meds_997223', 'Meds_997488', 'Meds_997501', 'Meds_999967', '65710008_x', 'Conds_10509002', 'Conds_109838007', 'Conds_110030002', 'Conds_11218009', 'Conds_124171000119105', 'Conds_126906006', 'Conds_127013003', 'Conds_127295002', 'Conds_128613002', 'Conds_1501000119109', 'Conds_1551000119108', 'Conds_156073000', 'Conds_157141000119108', 'Conds_15724005', 'Conds_15777000', 'Conds_16114001', 'Conds_161621004', 'Conds_161622006', 'Conds_162573006', 'Conds_162864005', 'Conds_1734006', 'Conds_185086009', 'Conds_190905008', 'Conds_19169002', 'Conds_192127007', 'Conds_195662009', 'Conds_195967001', 'Conds_196416002', 'Conds_197927001', 'Conds_198992004', 'Conds_200936003', 'Conds_201834006', 'Conds_206523001', 'Conds_22298006', 'Conds_225444004', 'Conds_230265002', 'Conds_230690007', 'Conds_232353008', 'Conds_233604007', 'Conds_233678006', 'Conds_235919008', 'Conds_236077008', 'Conds_237602007', 'Conds_239720000', 'Conds_239872002', 'Conds_239873007', 'Conds_24079001', 'Conds_241929008', 'Conds_254632001', 'Conds_254637007', 'Conds_254837009', 'Conds_262574004', 'Conds_263102004', 'Conds_26929004', 'Conds_271737000', 'Conds_275272006', 'Conds_283371005', 'Conds_283385000', 'Conds_284549007', 'Conds_284551006', 'Conds_301011002', 'Conds_302870006', 'Conds_307731004', 'Conds_30832001', 'Conds_314994000', 'Conds_33737001', 'Conds_359817006', 'Conds_35999006', 'Conds_363406005', 'Conds_367498001', 'Conds_368581000119106', 'Conds_36923009', 'Conds_36971009', 'Conds_370143000', 'Conds_370247008', 'Conds_38822007', 'Conds_398254007', 'Conds_39848009', 'Conds_399211009', 'Conds_40055000', 'Conds_40275004', 'Conds_403190006' ...

# %%
final_df.columns

# %%
standardize = [([col], StandardScaler()) for col in stand_cols]
leave = [(col, None) for col in leave_cols]
x_mapper_b = DataFrameMapper(standardize + leave)

standardize = [([col], StandardScaler()) for col in stand_cols]
leave = [(col, None) for col in leave_cols]
x_mapper_a = DataFrameMapper(standardize + leave)
#df_copy = df_train
#df_copy = df_copy.drop(columns='durration')
c_df = final_df
c_df = c_df.drop(columns= {'Id', 'durration','event'})
x_mapper_a.fit(c_df)
x_train = x_mapper_b.fit_transform(df_train).astype('float32')
x_val = x_mapper_b.transform(df_val).astype('float32')
x_test = x_mapper_b.transform(df_test).astype('float32')

# %%
print(c_df.columns)
# Out:
# Index(['1000126', '1014678', '1043400', '1049221', '1049630', '1049635',
#        '105078', '105585', '106258', '106892',
#        ...
#        'Proc_76601001', 'Proc_80146002', 'Proc_82078001', 'Proc_85548006',
#        'Proc_88039007', 'Proc_88848003', 'Proc_90226004', 'Proc_90407005',
#        'Proc_90470006', 'Proc_91602002'],
#       dtype='object', length=950)

# %%
get_target = lambda df: (df['durration'].values, df['event'].values)
y_train = get_target(df_train)
y_val = get_target(df_val)
durations_test, events_test = get_target(df_test)
val = tt.tuplefy(x_val, y_val)

val.shapes()

val.repeat(2).cat().shapes()
# Out:
# ((37692, 950), ((37692,), (37692,)))

# %%
in_features = x_train.shape[1]
num_nodes = [100, 100]
out_features = 1
batch_norm = True
dropout = 0.1
output_bias = False

net = tt.practical.MLPVanilla(in_features, num_nodes, out_features, batch_norm,
                              dropout, output_bias=output_bias)

# %%
model = CoxCC(net, tt.optim.Adam)
batch_size = 256
lrfinder = model.lr_finder(x_train, y_train, batch_size, tolerance=10)
_ = lrfinder.plot()

# %%
lrfinder.get_best_lr()
model.optimizer.set_lr(0.01)

# %%
epochs = 512
callbacks = [tt.callbacks.EarlyStopping()]
verbose = True

# %%
# %%time
log = model.fit(x_train, y_train, batch_size, epochs, callbacks, verbose,
                val_data=val.repeat(10).cat())
# Out:
# 0:	[0s / 0s],		train_loss: 0.5370,	val_loss: 0.5352
# 1:	[0s / 0s],		train_loss: 0.3760,	val_loss: 0.4896
# 2:	[0s / 0s],		train_loss: 0.3669,	val_loss: 0.3745
# 3:	[0s / 0s],		train_loss: 0.3644,	val_loss: 0.3267
# 4:	[0s / 0s],		train_loss: 0.3430,	val_loss: 0.2981
# 5:	[0s / 0s],		train_loss: 0.3371,	val_loss: 0.8080
# 6:	[0s / 0s],		train_loss: 0.3529,	val_loss: 0.3135
# 7:	[0s / 0s],		train_loss: 0.3512,	val_loss: 0.2824
# 8:	[0s / 0s],		train_loss: 0.3606,	val_loss: 0.2994
# 9:	[0s / 0s],		train_loss: 0.3248,	val_loss: 0.2730
# 10:	[0s / 1s],		train_loss: 0.3399,	val_loss: 0.3076
# 11:	[0s / 1s],		train_loss: 0.3356,	val_loss: 0.3147
# 12:	[0s / 1s],		train_loss: 0.3367,	val_loss: 0.3082
# 13:	[0s / 1s],		train_loss: 0.3113,	val_loss: 0.3048
# 14:	[0s / 1s],		train_loss: 0.3426,	val_loss: 0.3132
# 15:	[0s / 1s],		train_loss: 0.3403,	val_loss: 0.3087
# 16:	[0s / 1s],		train_loss: 0.3515,	val_loss: 0.2976
# 17:	[0s / 1s],		train_loss: 0.3094,	val_loss: 0.2816
# 18:	[0s / 1s],		train_loss: 0.3198,	val_loss: 0.2899
# 19:	[0s / 1s],		train_loss: 0.3290,	val_loss: 0.2972
# Wall time: 3.32 s

# %%
_ = log.plot()

# %%
model.partial_log_likelihood(*val).mean()
# Out:
# C:\Users\Konzelc\Anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# -5.753672122955322

# %%
_ = model.compute_baseline_hazards()
surv = model.predict_surv_df(x_test)
surv.iloc[:, 0:5].plot()
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')
# Out:
# C:\Users\Konzelc\Anaconda3\lib\site-packages\pycox\models\cox.py:237: RuntimeWarning: overflow encountered in exp
#   .assign(expg=np.exp(self.predict(input, batch_size, True, eval_, num_workers=num_workers)))
# C:\Users\Konzelc\Anaconda3\lib\site-packages\pycox\models\cox.py:257: RuntimeWarning: overflow encountered in exp
#   expg = np.exp(self.predict(input, batch_size, True, eval_, num_workers=num_workers)).reshape(1, -1)

# %%
cd = test_df.columns
co = final_df.columns
dropCols = []
for a in cd:
    if a not in co:
        dropCols.append(a)
print(dropCols)
# Out:
# ['1243052', 'Meds_1243052']

# %%
# Out:
# (23558, 950)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7a75f65d9167> in <module>
#       1 print(x_test.shape)
# ----> 2 print(pred_x.shape)
#
# NameError: name 'pred_x' is not defined

# %%
test_df = test_df.drop(columns=dropCols)
cols = test_df.columns
print(cols)

print(test_df.shape)

pred_x = x_mapper_a.transform(test_df).astype('float32')
print(test_df.columns)

surv2 = model.predict_surv_df(pred_x)
# Out:
# Index(['Id', '1000126', '1014678', '1043400', '1049221', '1049630', '1049635',
#        '105078', '105585', '106258',
#        ...
#        'Proc_76601001', 'Proc_80146002', 'Proc_82078001', 'Proc_85548006',
#        'Proc_88039007', 'Proc_88848003', 'Proc_90226004', 'Proc_90407005',
#        'Proc_90470006', 'Proc_91602002'],
#       dtype='object', length=951)
# (29040, 951)
# Index(['Id', '1000126', '1014678', '1043400', '1049221', '1049630', '1049635',
#        '105078', '105585', '106258',
#        ...
#        'Proc_76601001', 'Proc_80146002', 'Proc_82078001', 'Proc_85548006',
#        'Proc_88039007', 'Proc_88848003', 'Proc_90226004', 'Proc_90407005',
#        'Proc_90470006', 'Proc_91602002'],
#       dtype='object', length=951)
# C:\Users\Konzelc\Anaconda3\lib\site-packages\pycox\models\cox.py:257: RuntimeWarning: overflow encountered in exp
#   expg = np.exp(self.predict(input, batch_size, True, eval_, num_workers=num_workers)).reshape(1, -1)

# %%
surv2.iloc[:, :5].plot()
plt.ylabel('S(t | x)')
_ = plt.xlabel('Time')

# %%
i = 0
import csv
with open('test_Output_ICU.csv', 'w') as csvfile:
    testwriter = csv.writer(csvfile, delimiter=',')
    for i in range(len(surv2.iloc[0,:])):
        time = ((surv2.iloc[(surv2.iloc[:,i]-0.5).abs().argsort()[:1]][i]).index)[0]
        testwriter.writerow([test_df.iloc[i,0], time])

# %%
ev = EvalSurv(surv, durations_test, events_test, censor_surv='km')
ev.concordance_td()
# Out:
# 0.8525379505098024

# %%
time_grid = np.linspace(durations_test.min(), durations_test.max(), 100)
_ = ev.brier_score(time_grid).plot()

# %%
ev.integrated_brier_score(time_grid)
# Out:
# 0.08487251981593848

# %%
ev.integrated_nbll(time_grid)
# Out:
# 0.49391049225886413
